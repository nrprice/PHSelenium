# %%
import pandas as pd
import plotly as py
from plotly.subplots import make_subplots
import plotly.graph_objs as go
import plotly.express as px

PH = pd.read_json('pearsonham.txt', orient='index')

# %%
PH
# Out:
#                      name qualification  \
# 1                 Tim Ham           MBA
# 2       Jill Ridley-Smith           MBA
# 3     Guillaume Alexandre           MSc
# 4         Stephen Kennedy            MA
# 5            Ines Llerena    None Found
# 6          David Boothman    None Found
# 7              Nick Allen            BA
# 8           Julian Graves    None Found
# 9               Tom Wells           PhD
# 10    Johann Mulla-Feroze           MBA
# 11              Zeba Syed           MSc
# 12            Hazel Davis    None Found
# 13              Adam Jama          MEng
# 14          Musab Shamekh            BA
# 15      Emil Gawlik-Foged    None Found
# 16               Adam Way            BA
# 17  Shevket Halil Shevket           PhD
# 18              Dan Milne    None Found
# 19            Anish Patel    None Found
# 20         Beverley Leung    None Found
# 21          Rory Flanagan           MSc
# 22      Sasipa Tunprasert           BSc
# ...
